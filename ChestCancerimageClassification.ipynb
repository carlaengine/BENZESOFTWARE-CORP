# %% [markdown]
# <a href="https://colab.research.google.com/github/carlaengine/BENZESOFTWARE-CORP/blob/starter/ChestCancerimageClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2
import tensorflow as tf
import tensorflow_datasets as tfds
from matplotlib import pyplot as plt
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import MaxPooling2D, BatchNormalization
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import MobileNet, VGG16, ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import precision_score, recall_score, accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import seaborn as sns
import os

# %%
train_folder = "/content/drive/MyDrive/dataset/Data/train"
valid_folder = "/content/drive/MyDrive/dataset/Data/valid"
test_folder = "/content/drive/MyDrive/dataset/Data/test"

# %%
input_shape = (224,224,3)
num_classes = 4

train_datagen = ImageDataGenerator(
    dtype='float32',
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=False
)
val_datagen = ImageDataGenerator(
    dtype='float32',

)
test_datagen = ImageDataGenerator(
    dtype='float32',
)

train_generator = train_datagen.flow_from_directory(
    train_folder,
    target_size=(224,224),
    batch_size=64,
    class_mode='categorical',
)


test_generator = test_datagen.flow_from_directory(
    test_folder,
    target_size=(224,224),
    batch_size=64,
    class_mode='categorical',
    shuffle = False,
)
validation_generator = val_datagen.flow_from_directory(
    valid_folder,
    target_size=(224,224),
    batch_size=64,
    class_mode='categorical',
)
# Out:
# Found 613 images belonging to 4 classes.
# Found 315 images belonging to 4 classes.
# Found 72 images belonging to 4 classes.

# %%
from keras.applications import VGG16
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, Flatten, Dense, GlobalAveragePooling2D, Reshape, Multiply

def squeeze_excitation_block(input, ratio=16):
    init = input
    channel_axis = -1
    filters = init.shape[channel_axis]
    se_shape = (1, 1, filters)

    se = GlobalAveragePooling2D()(init)
    se = Reshape(se_shape)(se)
    se = Dense(filters // ratio, activation='relu', kernel_initializer='he_normal', use_bias=False)(se)
    se = Dense(filters, activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(se)

    x = Multiply()([init, se])
    return x

def residual_block(x, filters, kernel_size, stride):
    shortcut = x
    x = Conv2D(filters, kernel_size, strides=stride, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(filters, kernel_size, padding='same')(x)
    x = BatchNormalization()(x)
    x = squeeze_excitation_block(x)
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

input_tensor = Input(shape=(224, 224, 3))
vgg16 = VGG16(include_top=False, weights='imagenet', input_tensor=input_tensor)

x = vgg16.layers[-1].output
x = residual_block(x, 512, 3, 1)
x = residual_block(x, 512, 3, 1)
x = BatchNormalization()(x)
x = Flatten()(x)
x = Dense(1024, activation='relu')(x)
x = Dense(512, activation='relu')(x)
predictions = Dense(4, activation='softmax')(x)
model = Model(inputs=input_tensor, outputs=predictions)
model.summary()

optimizer = tf.keras.optimizers.SGD()
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

epochs = 100
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs,
    verbose=1
)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)         1792      ['input_2[0][0]']
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)         36928     ['block1_conv1[0][0]']
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)         0         ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)        73856     ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)        147584    ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)          0         ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)          295168    ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)          590080    ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)          590080    ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)          0         ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)          1180160   ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)          2359808   ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)          2359808   ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)          0         ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)          2359808   ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)          2359808   ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)          2359808   ['block5_conv2[0][0]']
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)            0         ['block5_conv3[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 512)            2359808   ['block5_pool[0][0]']
#
#  batch_normalization_5 (Bat  (None, 7, 7, 512)            2048      ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 7, 7, 512)            0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 512)            2359808   ['activation_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 7, 7, 512)            2048      ['conv2d_5[0][0]']
#  chNormalization)
#
#  global_average_pooling2d_2  (None, 512)                  0         ['batch_normalization_6[0][0]'
#   (GlobalAveragePooling2D)                                          ]
#
#  reshape_2 (Reshape)         (None, 1, 1, 512)            0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_7 (Dense)             (None, 1, 1, 32)             16384     ['reshape_2[0][0]']
#
#  dense_8 (Dense)             (None, 1, 1, 512)            16384     ['dense_7[0][0]']
#
#  multiply_2 (Multiply)       (None, 7, 7, 512)            0         ['batch_normalization_6[0][0]'
#                                                                     , 'dense_8[0][0]']
#
#  add_2 (Add)                 (None, 7, 7, 512)            0         ['multiply_2[0][0]',
#                                                                      'block5_pool[0][0]']
#
#  activation_5 (Activation)   (None, 7, 7, 512)            0         ['add_2[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 7, 7, 512)            2359808   ['activation_5[0][0]']
#
#  batch_normalization_7 (Bat  (None, 7, 7, 512)            2048      ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 7, 7, 512)            0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 512)            2359808   ['activation_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 7, 7, 512)            2048      ['conv2d_7[0][0]']
#  chNormalization)
#
#  global_average_pooling2d_3  (None, 512)                  0         ['batch_normalization_8[0][0]'
#   (GlobalAveragePooling2D)                                          ]
#
#  reshape_3 (Reshape)         (None, 1, 1, 512)            0         ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  dense_9 (Dense)             (None, 1, 1, 32)             16384     ['reshape_3[0][0]']
#
#  dense_10 (Dense)            (None, 1, 1, 512)            16384     ['dense_9[0][0]']
#
#  multiply_3 (Multiply)       (None, 7, 7, 512)            0         ['batch_normalization_8[0][0]'
#                                                                     , 'dense_10[0][0]']
#
#  add_3 (Add)                 (None, 7, 7, 512)            0         ['multiply_3[0][0]',
#                                                                      'activation_5[0][0]']
#
#  activation_7 (Activation)   (None, 7, 7, 512)            0         ['add_3[0][0]']
#
#  batch_normalization_9 (Bat  (None, 7, 7, 512)            2048      ['activation_7[0][0]']
#  chNormalization)
#
#  flatten_1 (Flatten)         (None, 25088)                0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  dense_11 (Dense)            (None, 1024)                 2569113   ['flatten_1[0][0]']
#                                                           6
#
#  dense_12 (Dense)            (None, 512)                  524800    ['dense_11[0][0]']
#
#  dense_13 (Dense)            (None, 4)                    2052      ['dense_12[0][0]']
#
# ==================================================================================================
# Total params: 50447684 (192.44 MB)
# Trainable params: 50442564 (192.42 MB)
# Non-trainable params: 5120 (20.00 KB)
# __________________________________________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 143s 13s/step - loss: 1.7496 - accuracy: 0.3768 - val_loss: 26.7730 - val_accuracy: 0.1806
# Epoch 2/100
# 10/10 [==============================] - 88s 9s/step - loss: 1.3652 - accuracy: 0.4617 - val_loss: 50.2414 - val_accuracy: 0.1806
# Epoch 3/100
# 10/10 [==============================] - 88s 9s/step - loss: 1.0807 - accuracy: 0.5334 - val_loss: 5.7093 - val_accuracy: 0.1806
# Epoch 4/100
# 10/10 [==============================] - 89s 9s/step - loss: 0.8963 - accuracy: 0.5824 - val_loss: 2.3127 - val_accuracy: 0.2361
# Epoch 5/100
# 10/10 [==============================] - 89s 9s/step - loss: 0.8542 - accuracy: 0.6101 - val_loss: 4.2641 - val_accuracy: 0.1806
# Epoch 6/100
# 10/10 [==============================] - 89s 9s/step - loss: 0.7340 - accuracy: 0.6672 - val_loss: 2.0965 - val_accuracy: 0.4444
# Epoch 7/100
# 10/10 [==============================] - 89s 9s/step - loss: 0.6730 - accuracy: 0.7145 - val_loss: 1.1915 - val_accuracy: 0.5972
# Epoch 8/100
# 10/10 [==============================] - 89s 9s/step - loss: 0.7423 - accuracy: 0.6852 - val_loss: 2.2569 - val_accuracy: 0.3194
# Epoch 9/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.5783 - accuracy: 0.7586 - val_loss: 1.8435 - val_accuracy: 0.4583
# Epoch 10/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.5685 - accuracy: 0.7635 - val_loss: 1.1640 - val_accuracy: 0.5694
# Epoch 11/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.6464 - accuracy: 0.7259 - val_loss: 1.3758 - val_accuracy: 0.5278
# Epoch 12/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.4483 - accuracy: 0.8206 - val_loss: 1.2457 - val_accuracy: 0.5833
# Epoch 13/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.3555 - accuracy: 0.8581 - val_loss: 1.0067 - val_accuracy: 0.5972
# Epoch 14/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.4331 - accuracy: 0.8320 - val_loss: 1.8100 - val_accuracy: 0.4861
# Epoch 15/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.3798 - accuracy: 0.8385 - val_loss: 0.6954 - val_accuracy: 0.6528
# Epoch 16/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.3127 - accuracy: 0.8760 - val_loss: 0.8178 - val_accuracy: 0.6806
# Epoch 17/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.2715 - accuracy: 0.8989 - val_loss: 0.9575 - val_accuracy: 0.6667
# Epoch 18/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.2539 - accuracy: 0.9054 - val_loss: 0.8618 - val_accuracy: 0.7361
# Epoch 19/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.2064 - accuracy: 0.9266 - val_loss: 0.6700 - val_accuracy: 0.8194
# Epoch 20/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.2728 - accuracy: 0.8972 - val_loss: 1.3346 - val_accuracy: 0.5972
# Epoch 21/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.1797 - accuracy: 0.9331 - val_loss: 0.7083 - val_accuracy: 0.7778
# Epoch 22/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.2037 - accuracy: 0.9347 - val_loss: 1.0403 - val_accuracy: 0.6250
# Epoch 23/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.2324 - accuracy: 0.9021 - val_loss: 0.5590 - val_accuracy: 0.8611
# Epoch 24/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.1084 - accuracy: 0.9690 - val_loss: 0.5016 - val_accuracy: 0.8750
# Epoch 25/100
# 10/10 [==============================] - 86s 9s/step - loss: 0.1285 - accuracy: 0.9625 - val_loss: 0.8878 - val_accuracy: 0.7361
# Epoch 26/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.1018 - accuracy: 0.9592 - val_loss: 1.0021 - val_accuracy: 0.7083
# Epoch 27/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0827 - accuracy: 0.9755 - val_loss: 0.5854 - val_accuracy: 0.8611
# Epoch 28/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.1418 - accuracy: 0.9445 - val_loss: 0.5345 - val_accuracy: 0.9167
# Epoch 29/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0868 - accuracy: 0.9690 - val_loss: 0.6869 - val_accuracy: 0.7500
# Epoch 30/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0790 - accuracy: 0.9788 - val_loss: 2.8901 - val_accuracy: 0.5139
# Epoch 31/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.2379 - accuracy: 0.9168 - val_loss: 0.6055 - val_accuracy: 0.8472
# Epoch 32/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.1021 - accuracy: 0.9657 - val_loss: 0.8477 - val_accuracy: 0.7083
# Epoch 33/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0653 - accuracy: 0.9804 - val_loss: 0.6594 - val_accuracy: 0.8750
# Epoch 34/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0416 - accuracy: 0.9902 - val_loss: 0.5538 - val_accuracy: 0.9028
# Epoch 35/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0325 - accuracy: 0.9886 - val_loss: 0.5586 - val_accuracy: 0.8750
# Epoch 36/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0613 - accuracy: 0.9788 - val_loss: 0.5915 - val_accuracy: 0.8889
# Epoch 37/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0278 - accuracy: 0.9935 - val_loss: 0.4814 - val_accuracy: 0.9028
# Epoch 38/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0771 - accuracy: 0.9706 - val_loss: 0.3984 - val_accuracy: 0.9028
# Epoch 39/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0523 - accuracy: 0.9886 - val_loss: 0.5340 - val_accuracy: 0.8750
# Epoch 40/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0380 - accuracy: 0.9935 - val_loss: 0.7875 - val_accuracy: 0.8750
# Epoch 41/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.1168 - accuracy: 0.9657 - val_loss: 0.9041 - val_accuracy: 0.8056
# Epoch 42/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0268 - accuracy: 0.9951 - val_loss: 0.4975 - val_accuracy: 0.9167
# Epoch 43/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0367 - accuracy: 0.9853 - val_loss: 0.6737 - val_accuracy: 0.8472
# Epoch 44/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0463 - accuracy: 0.9837 - val_loss: 0.8916 - val_accuracy: 0.8611
# Epoch 45/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0266 - accuracy: 0.9951 - val_loss: 0.6579 - val_accuracy: 0.8750
# Epoch 46/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0171 - accuracy: 0.9935 - val_loss: 0.6548 - val_accuracy: 0.9167
# Epoch 47/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0228 - accuracy: 0.9951 - val_loss: 0.5502 - val_accuracy: 0.8750
# Epoch 48/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0204 - accuracy: 0.9918 - val_loss: 0.5882 - val_accuracy: 0.9028
# Epoch 49/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0097 - accuracy: 0.9984 - val_loss: 0.6581 - val_accuracy: 0.9167
# Epoch 50/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0439 - accuracy: 0.9837 - val_loss: 2.2563 - val_accuracy: 0.6528
# Epoch 51/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0600 - accuracy: 0.9739 - val_loss: 0.5848 - val_accuracy: 0.8889
# Epoch 52/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0366 - accuracy: 0.9853 - val_loss: 0.5692 - val_accuracy: 0.9167
# Epoch 53/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0165 - accuracy: 0.9984 - val_loss: 0.5466 - val_accuracy: 0.9444
# Epoch 54/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0161 - accuracy: 0.9918 - val_loss: 0.5610 - val_accuracy: 0.8611
# Epoch 55/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0166 - accuracy: 0.9935 - val_loss: 0.8500 - val_accuracy: 0.8750
# Epoch 56/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0379 - accuracy: 0.9886 - val_loss: 0.5764 - val_accuracy: 0.8750
# Epoch 57/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0180 - accuracy: 0.9951 - val_loss: 0.8179 - val_accuracy: 0.8472
# Epoch 58/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0105 - accuracy: 0.9984 - val_loss: 0.5485 - val_accuracy: 0.9444
# Epoch 59/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0176 - accuracy: 0.9935 - val_loss: 0.8328 - val_accuracy: 0.9028
# Epoch 60/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0217 - accuracy: 0.9918 - val_loss: 0.6622 - val_accuracy: 0.9167
# Epoch 61/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0155 - accuracy: 0.9935 - val_loss: 0.9456 - val_accuracy: 0.8889
# Epoch 62/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.9225 - val_accuracy: 0.8750
# Epoch 63/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0185 - accuracy: 0.9967 - val_loss: 0.6225 - val_accuracy: 0.9028
# Epoch 64/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0148 - accuracy: 0.9967 - val_loss: 1.6932 - val_accuracy: 0.6111
# Epoch 65/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0378 - accuracy: 0.9902 - val_loss: 0.6626 - val_accuracy: 0.8056
# Epoch 66/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0139 - accuracy: 0.9967 - val_loss: 0.5993 - val_accuracy: 0.9167
# Epoch 67/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.8784 - val_accuracy: 0.8889
# Epoch 68/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0097 - accuracy: 0.9984 - val_loss: 0.8754 - val_accuracy: 0.9167
# Epoch 69/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.9542 - val_accuracy: 0.9028
# Epoch 70/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0172 - accuracy: 0.9951 - val_loss: 0.9118 - val_accuracy: 0.8333
# Epoch 71/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0141 - accuracy: 0.9967 - val_loss: 0.9061 - val_accuracy: 0.9028
# Epoch 72/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0098 - accuracy: 0.9951 - val_loss: 0.9094 - val_accuracy: 0.8889
# Epoch 73/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.7631 - val_accuracy: 0.8889
# Epoch 74/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.8120 - val_accuracy: 0.9167
# Epoch 75/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0057 - accuracy: 0.9967 - val_loss: 0.7358 - val_accuracy: 0.9306
# Epoch 76/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.8319 - val_accuracy: 0.8889
# Epoch 77/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.0360 - val_accuracy: 0.8750
# Epoch 78/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0120 - accuracy: 0.9967 - val_loss: 0.7837 - val_accuracy: 0.9028
# Epoch 79/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0080 - accuracy: 0.9967 - val_loss: 0.7896 - val_accuracy: 0.9306
# Epoch 80/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0180 - accuracy: 0.9951 - val_loss: 0.7773 - val_accuracy: 0.9167
# Epoch 81/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0122 - accuracy: 0.9935 - val_loss: 0.7279 - val_accuracy: 0.9167
# Epoch 82/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0380 - accuracy: 0.9935 - val_loss: 0.8142 - val_accuracy: 0.9167
# Epoch 83/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.9508 - val_accuracy: 0.9167
# Epoch 84/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0391 - accuracy: 0.9821 - val_loss: 10.7627 - val_accuracy: 0.3750
# Epoch 85/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.5906 - accuracy: 0.8287 - val_loss: 1.4119 - val_accuracy: 0.7639
# Epoch 86/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0512 - accuracy: 0.9869 - val_loss: 0.8561 - val_accuracy: 0.8472
# Epoch 87/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0220 - accuracy: 0.9935 - val_loss: 0.8111 - val_accuracy: 0.8611
# Epoch 88/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0212 - accuracy: 0.9935 - val_loss: 0.8823 - val_accuracy: 0.9028
# Epoch 89/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0190 - accuracy: 0.9951 - val_loss: 0.9897 - val_accuracy: 0.8611
# Epoch 90/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0258 - accuracy: 0.9918 - val_loss: 0.7814 - val_accuracy: 0.9028
# Epoch 91/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0204 - accuracy: 0.9935 - val_loss: 1.2081 - val_accuracy: 0.7778
# Epoch 92/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0151 - accuracy: 0.9967 - val_loss: 1.0360 - val_accuracy: 0.8611
# Epoch 93/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.7702 - val_accuracy: 0.9306
# Epoch 94/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0098 - accuracy: 0.9984 - val_loss: 0.8582 - val_accuracy: 0.9167
# Epoch 95/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.8558 - val_accuracy: 0.9306
# Epoch 96/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0072 - accuracy: 0.9984 - val_loss: 0.8485 - val_accuracy: 0.9167
# Epoch 97/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0074 - accuracy: 0.9967 - val_loss: 0.8816 - val_accuracy: 0.9028
# Epoch 98/100
# 10/10 [==============================] - 88s 9s/step - loss: 0.0099 - accuracy: 0.9984 - val_loss: 0.9065 - val_accuracy: 0.8889
# Epoch 99/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0138 - accuracy: 0.9984 - val_loss: 1.1365 - val_accuracy: 0.8889
# Epoch 100/100
# 10/10 [==============================] - 87s 9s/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.9007 - val_accuracy: 0.9167

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print('Test accuracy:', test_accuracy)
# Out:
# 5/5 [==============================] - 63s 15s/step - loss: 0.2813 - accuracy: 0.9206
# Test accuracy: 0.920634925365448

# %%
num_test_samples = len(test_generator)
num_classes = len(test_generator.class_indices)
predicted_probabilities = model.predict(test_generator, steps=num_test_samples)
predicted_labels = np.argmax(predicted_probabilities, axis=1)
true_labels = test_generator.classes
cm = confusion_matrix(true_labels, predicted_labels)
print("\n\nConfusion Matrix:\n", cm)

plt.figure(figsize=(10,4))
sns.heatmap(cm, annot=True, fmt='g', cmap='Reds')
plt.xlabel('\n\nPredicted Label\n')
plt.ylabel('\nTrue Label\n')
plt.title('Confusion Matrix\n\n')
plt.show()
# Out:
# 5/5 [==============================] - 7s 1s/step
#
#
# Confusion Matrix:
#  [[112   5   0   3]
#  [  2  49   0   0]
#  [  1   0  53   0]
#  [ 10   4   0  76]]

# %%
history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(acc_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label = 'Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label = 'Training Accuracy')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label = 'Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label = 'Training Loss')

plt.setp(line1)
plt.setp(line2)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float
#   agg_filter: a filter function, which takes a (m, n, 3) float array and a dpi value, and returns a (m, n, 3) array and two offsets from the bottom left corner of the image
#   alpha: scalar or None
#   animated: bool
#   antialiased or aa: bool
#   clip_box: `.Bbox`
#   clip_on: bool
#   clip_path: Patch or (Path, Transform) or None
#   color or c: color
#   dash_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   dash_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   dashes: sequence of floats (on/off ink in points) or (None, None)
#   data: (2, N) array or two 1D arrays
#   drawstyle or ds: {'default', 'steps', 'steps-pre', 'steps-mid', 'steps-post'}, default: 'default'
#   figure: `.Figure`
#   fillstyle: {'full', 'left', 'right', 'bottom', 'top', 'none'}
#   gapcolor: color or None
#   gid: str
#   in_layout: bool
#   label: object
#   linestyle or ls: {'-', '--', '-.', ':', '', (offset, on-off-seq), ...}
#   linewidth or lw: float
#   marker: marker style string, `~.path.Path` or `~.markers.MarkerStyle`
#   markeredgecolor or mec: color
#   markeredgewidth or mew: float
#   markerfacecolor or mfc: color
#   markerfacecoloralt or mfcalt: color
#   markersize or ms: float
#   markevery: None or int or (int, int) or slice or list[int] or float or (float, float) or list[bool]
#   mouseover: bool
#   path_effects: `.AbstractPathEffect`
#   picker: float or callable[[Artist, Event], tuple[bool, dict]]
#   pickradius: unknown
#   rasterized: bool
#   sketch_params: (scale: float, length: float, randomness: float)
#   snap: bool or None
#   solid_capstyle: `.CapStyle` or {'butt', 'projecting', 'round'}
#   solid_joinstyle: `.JoinStyle` or {'miter', 'round', 'bevel'}
#   transform: `.Transform`
#   url: str
#   visible: bool
#   xdata: 1D array
#   ydata: 1D array
#   zorder: float

# %%
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91       120
#            1       0.84      0.96      0.90        51
#            2       1.00      0.98      0.99        54
#            3       0.96      0.84      0.90        90
#
#     accuracy                           0.92       315
#    macro avg       0.93      0.93      0.93       315
# weighted avg       0.92      0.92      0.92       315
